# %%
import pandas as pd

# %%
programas = pd.read_table("programas.txt", header=None)

# %%
programas.head()
# Out:
#                                                    0
# 0           1,1,"tecnologia en gestion de marketing"
# 1  2,1,"administracion en seguridad y salud en el...
# 2                             3,3,"ingenieria civil"
# 3           4,3,tecnologia en produccion industrial"
# 4  5,3,"tecnologia en seguridad e higiene ocupaci...

# %%
programas[0].str.split(",", expand=True)
# Out:
#      0  1                                                  2
# 0    1  1               "tecnologia en gestion de marketing"
# 1    2  1  "administracion en seguridad y salud en el tra...
# 2    3  3                                 "ingenieria civil"
# 3    4  3               tecnologia en produccion industrial"
# 4    5  3    "tecnologia en seguridad e higiene ocupacional"
# 5    6  3                 "tecnologia en control de calidad"
# 6    7  3       "tecnologia en gestion ambiental industrial"
# 7    8  3  "tecnologia en operacion de plantas y procesos...
# 8    9  3         "tecnologia en instrumentacion industrial"
# 9   10  3    "tecnologia en control electronico de procesos"
# 10  11  3             "tecnologia en desarrollo de software"
# 11  12  3  "tecnologia en redes de comunicaciones y servi...
# 12  13  3                           "ingenieria industrial"
# 13  14  2                                          "derecho"
# ...
